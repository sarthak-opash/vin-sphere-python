# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/dataset_sample_10k_rows.csv")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3168\3209986515.py:1: DtypeWarning: Columns (13,19,25,52,55,56,57,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,95,96,97,98,99,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,126,127,132,134,135,136,137,138,139,140,152,154,155,156,158,159,160,161,162,164,165,166,167,169,170) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../Data/dataset_sample_10k_rows.csv")

# %%
df
# Out:
#                            _id      make   model              trim  \
# 0     68592fc0f32ddc587c27aafb    TOYOTA   HIACE                DX
# 1     685935005d8bb5f0ab18a181    TOYOTA   HIACE                DX
# 2     685944995d8bb5f0ab18bafc    TOYOTA   HILUX                DL
# 3     68596237e6bdae3db611dab9  INFINITI    QX50        LUXE STYLE
# 4     685bb1456ce98addfc08ed19       BMW    420I   M SPORT PREMIUM
# ...                        ...       ...     ...               ...
# 9995  68dcceb676ce7b9ceab640e5   HYUNDAI  SONATA            GL TOP
# 9996  68dcceb776ce7b9ceab64122     HONDA    CR-V                LX
# 9997  68dccedb76ce7b9ceab64535    NISSAN  PATROL  LE PLATINUM CITY
# 9998  68dccee376ce7b9ceab647a6    NISSAN   KICKS                 S
# 9999  68dccf4a76ce7b9ceab64e08    NISSAN  PATROL             SE T2
#
#                 bodyType  cylinders  year     insureType      chassisNumber  \
# 0     Mini Bus High Roof        4.0  2015     thirdparty  JTFHX02P7F0094323
# ...

# %%
df.loc[df["make"] == "NISSAN", ["make", "model", "trim", "bodyType", "cylinders", "year", "chassisNumber"]]
# Out:
#         make       model              trim bodyType  cylinders  year  \
# 22    NISSAN      PATROL       SE TITANIUM      SUV        6.0  2021
# 25    NISSAN      PATROL             SE T1      SUV        8.0  2013
# 26    NISSAN      PATROL             SE T1      SUV        8.0  2013
# 31    NISSAN      PATROL             SE T2      SUV        8.0  2016
# 33    NISSAN  PATHFINDER        CLASSIC XE      SUV        6.0  2014
# ...      ...         ...               ...      ...        ...   ...
# 9984  NISSAN      ALTIMA                SV    SEDAN        4.0  2020
# 9994  NISSAN      ALTIMA                SL    SEDAN        4.0  2014
# 9997  NISSAN      PATROL  LE PLATINUM CITY      SUV        8.0  2015
# 9998  NISSAN       KICKS                 S      SUV        4.0  2018
# 9999  NISSAN      PATROL             SE T2      SUV        6.0  2019
#
#           chassisNumber
# 22    JN8BY2NY7M9346550
# 25    JN8AY2NY7D9069894
# 26    JN8AY2NY7D9069894
# 31    JN8AY2NY1G9212861
# ...

# %%
df["chassis_attribute"] = df["chassisNumber"].str[3:8]

# %%
df["chassis_attribute"]
# Out:
# 0       HX02P
# 1       HX02P
# 2       HXDGP
# 3       ASNYC
# 4       11AP0
#         ...
# 9995    E34AF
# 9996    RM485
# 9997    AY2NY
# 9998    CP5C9
# 9999    BY2NY
# Name: chassis_attribute, Length: 10000, dtype: object

# %%
df_nissan = df.loc[df["make"] == "NISSAN", ["make", "model", "trim", "bodyType", "cylinders", "year", "chassisNumber", "chassis_attribute"]]

# %%
df_nissan
# Out:
#         make       model              trim bodyType  cylinders  year  \
# 22    NISSAN      PATROL       SE TITANIUM      SUV        6.0  2021
# 25    NISSAN      PATROL             SE T1      SUV        8.0  2013
# 26    NISSAN      PATROL             SE T1      SUV        8.0  2013
# 31    NISSAN      PATROL             SE T2      SUV        8.0  2016
# 33    NISSAN  PATHFINDER        CLASSIC XE      SUV        6.0  2014
# ...      ...         ...               ...      ...        ...   ...
# 9984  NISSAN      ALTIMA                SV    SEDAN        4.0  2020
# 9994  NISSAN      ALTIMA                SL    SEDAN        4.0  2014
# 9997  NISSAN      PATROL  LE PLATINUM CITY      SUV        8.0  2015
# 9998  NISSAN       KICKS                 S      SUV        4.0  2018
# 9999  NISSAN      PATROL             SE T2      SUV        6.0  2019
#
#           chassisNumber chassis_attribute
# 22    JN8BY2NY7M9346550             BY2NY
# 25    JN8AY2NY7D9069894             AY2NY
# ...

# %%
df_nissan.to_csv("../Data/nissan_data.csv", index=False)
