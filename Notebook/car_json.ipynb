# %%
import pandas as pd

# %%
df = pd.read_json("../Data/carmodel.cleaned.json")

# %%
df
# Out:
#               name                                               logo
# 0           TOYOTA  https://www.carlogos.org/car-logos/toyota-logo...
# 1           NISSAN  https://www.carlogos.org/car-logos/nissan-logo...
# 2             AUDI   https://www.carlogos.org/car-logos/audi-logo.png
# 3              BMW    https://www.carlogos.org/car-logos/bmw-logo.png
# 4    MERCEDES BENZ  https://www.carlogos.org/car-logos/mercedes-be...
# ..             ...                                                ...
# 244          ZOTYE  https://www.carlogos.org/car-logos/zotye-logo.png
# 245             ZX  https://upload.wikimedia.org/wikipedia/en/8/8a...
# 246         ZXAUTO  https://upload.wikimedia.org/wikipedia/en/8/8a...
# 247      Zhongtong  https://www.carlogos.org/car-logos/zhongtong-l...
# 248           iCAR  https://upload.wikimedia.org/wikipedia/commons...
#
# [249 rows x 2 columns]

# %%
df["name"].value_counts()
# Out:
# name
# TOYOTA           1
# NISSAN           1
# AUDI             1
# BMW              1
# MERCEDES BENZ    1
#                 ..
# ZOTYE            1
# ZX               1
# ZXAUTO           1
# Zhongtong        1
# iCAR             1
# Name: count, Length: 249, dtype: int64
