# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/nissan_data.csv")

# %%
df
# Out:
#         make       model              trim bodyType  cylinders  year  \
# 0     NISSAN      PATROL       SE TITANIUM      SUV        6.0  2021
# 1     NISSAN      PATROL             SE T1      SUV        8.0  2013
# 2     NISSAN      PATROL             SE T1      SUV        8.0  2013
# 3     NISSAN      PATROL             SE T2      SUV        8.0  2016
# 4     NISSAN  PATHFINDER        CLASSIC XE      SUV        6.0  2014
# ...      ...         ...               ...      ...        ...   ...
# 2097  NISSAN      ALTIMA                SV    SEDAN        4.0  2020
# 2098  NISSAN      ALTIMA                SL    SEDAN        4.0  2014
# 2099  NISSAN      PATROL  LE PLATINUM CITY      SUV        8.0  2015
# 2100  NISSAN       KICKS                 S      SUV        4.0  2018
# 2101  NISSAN      PATROL             SE T2      SUV        6.0  2019
#
#           chassisNumber chassis_attribute
# 0     JN8BY2NY7M9346550             BY2NY
# 1     JN8AY2NY7D9069894             AY2NY
# ...
